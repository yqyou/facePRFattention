# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.io as sio
from scipy import stats
import scikits.bootstrap as boot
import seaborn as sns
import pingouin as pg
from sklearn import svm
from sklearn.model_selection import train_test_split,cross_val_score,cross_val_predict,cross_validate
from sklearn.metrics import accuracy_score
from scipy.stats import ttest_rel,wilcoxon
import os,math,mat73,sys
from functions import mybarplot,fisherztrans,myheatmap,corr_batch_nan
from joblib import Parallel, delayed
from datetime import datetime
from tqdm import tqdm

### set parameters

subjs = ['CN040','CN041']
hemi = ['lh','rh']
tasks = ['face','fixation']
roi_labels = ['V1','V2','V3']

nsubj = len(subjs)
nvoxel = 100
ntrial = 1280
ntrialperpos = 80
npos=16
ds0 = 2 # degree

cm = np.array([[255, 107, 129],[112, 161, 255]])/255

ds_list = np.zeros((npos,npos))
for s1 in range(npos):
    r1 = s1//4
    c1 = s1%4
    for s2 in range(s1):
        r2 = s2//4
        c2 = s2%4
        ds_list[s1,s2] = ((r1-r2)**2+(c1-c2)**2)**0.5*ds0
d = np.unique(ds_list)[1:]

nsample = nsubj * np.max([ds_list[ds_list==dd].shape for dd in d[1:]])

ps_list = np.zeros(npos)
for s in range(npos):
    sr = s//4*2
    sc = s%4*2
    ps_list[s] = ((5-sr)**2+(5-sc)**2)**0.5
posd = np.unique(ps_list)
nsample0 = nsubj * np.max([ps_list[ps_list==pp].shape for pp in posd])

# %%
## Load data

data = np.load('../exampledata/selectdata.npz',allow_pickle=True)
stimposicond_all = data['stimposicond_all']
v_sel_all = data['v_sel_all']
r2_sel_all = data['r2_sel_all']
beta_all = data['beta_sel_all']
prf_sel_all = data['prf_sel_all']

# stimposicond_all: [tasks * trial x sample]
# v_sel_all : roi x sample x voxel, from 0
# r2_sel_all : roi x sample x voxel x 2[glmr2,prfr2]
# beta_sel_all: task x roi x sample x voxel x trial
# prf_sel_all: task x roi x sample x voxel x 8

# %% [markdown]
# ### 1 SVM classification

# %%
clf = svm.SVC(C=1,kernel='linear',gamma='scale',degree=3)
y = np.hstack([np.zeros(ntrialperpos),np.zeros(ntrialperpos)+1])
acc_ij_all = np.zeros((npos,npos,nsubj,len(roi_labels),len(tasks)))*np.nan # [npos(s1),npos(s2),nsubj,nroi,ntask]

for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        for subj_i in range(len(subjs)):
            stimposicond = stimposicond_all[task_i,subj_i,:]
            # beta for each position (trial-by-trial)
            beta = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
            for pos in range(npos):
                beta[:,:,pos] = beta_all[task_i,roi_i,subj_i,:,stimposicond==pos+1].T
            for s1 in range(npos):
                for s2 in range(s1,npos):  
                    X = np.hstack([beta[:,:,s1],beta[:,:,s2]]).T
                    X = X[:,~np.isnan(X).any(axis=0)]
                    scores = cross_val_score(clf,X,y,cv=10,n_jobs=35)
                    acc_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,task_i] = np.array([scores.mean(),scores.mean()])

# concat reuslts by distance
acc_d = np.zeros((len(d),nsample,len(roi_labels),len(tasks)))*np.nan # d x sample x roi x task
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        for dd in range(len(d)):
            acc_dd = np.array([])
            for subj_i in range(len(subjs)):
                acc_dd = np.append(acc_dd,acc_ij_all[ds_list==d[dd],subj_i,roi_i,task_i])
            acc_d[dd,0:len(acc_dd),roi_i,task_i] = acc_dd


# average accuracy across position pairs for each distance for each subject
acc_d_subj = np.zeros((len(d),nsubj,len(roi_labels),len(tasks)))*np.nan # d x subj x roi x task
for dd in range(len(d)):
    acc_d_subj[dd,:,:,:] = np.nanmean(acc_ij_all[ds_list==d[dd],:,:,:],axis=0)

np.savez('../expectedoutput/svmacc',acc_ij_all=acc_ij_all,acc_d=acc_d,acc_d_subj=acc_d_subj)

# %% [markdown]
# ### 2 individual level

# %% [markdown]
# #### 2.0 vRF

# %%
vRF_allv = prf_sel_all # ntask x nroi x nsubj x nvoxel x 8
vRF_all = np.nanmedian(vRF_allv,axis=3) # ntask x nroi x nsubj x 8
# 0-R2, 1-x, 2-y, 3-ecc, 4-ang, 5-size, 6-expt, 7-gain
np.savez('../expectedoutput/vRF',vRF_allv=vRF_allv,vRF_all=vRF_all)

# %% [markdown]
# #### 2.1 Fano Factor

# %% [markdown]
# The ratio of the variance to the mean is often called the **Fano factor** and is a measure of the variability in the number of spikes in relation to the mean number of spikes:
#
# $$
# FF(T)≡\frac{σ_{N(0,T)}^2}{m_{N(0,T)}}
# $$
# $$
# FF_i = \frac{v_i}{b_i}
# $$
# $$
# FF^n = median(FF_i)
# $$

# %%
# calculate
FF_p_all = np.zeros((npos,nsubj,len(roi_labels),len(tasks)))*np.nan # [npos(s1),nsubj,nroi,ntask]
FFv_all = np.zeros((nvoxel,npos,nsubj,len(roi_labels),len(tasks)))*np.nan # [nvoxel,npos(s1),nsubj,nroi,ntask]
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        for subj_i in range(len(subjs)):
            stimposicond = stimposicond_all[task_i,subj_i,:]
            # beta for each position (trial-by-trial)
            beta = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
            beta_mean = np.zeros((nvoxel,npos))*np.nan
            for pos in range(npos):
                beta[:,:,pos] = beta_all[task_i,roi_i,subj_i,:,stimposicond==pos+1].T
                beta_mean[:,pos] = np.nanmean(beta[:,:,pos],axis=1)
                v = np.var(beta[:,:,pos],axis=1) # 100
                f = np.mat(beta_mean[:,pos]) # 1 x 100
                # 1 x 100
                # abs
                FF_n = np.multiply(v,abs(1/f))
                FFv_all[:,pos,subj_i,roi_i,task_i] = np.array(FF_n)
                FF_p_all[pos,subj_i,roi_i,task_i] = np.nanmedian(np.array(FF_n))

# concat data across position
FF_all = np.zeros((npos*nsubj,len(roi_labels),len(tasks)))*np.nan
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        c = np.array([])
        for subj_i in range(len(subjs)):
            c = np.append(c,FF_p_all[:,subj_i,roi_i,task_i])
        FF_all[:,roi_i,task_i] = c

np.savez('../expectedoutput/FF',FF_p_all=FF_p_all,FF_all=FF_all,FFv_all=FFv_all)

# %% [markdown]
# #### 2.2 Variance

# %%
# calculate
rv_p_all = np.zeros((npos,nsubj,len(roi_labels),len(tasks)))*np.nan # [npos(s1),nsubj,nroi,ntask]
rvv_all = np.zeros((nvoxel,npos,nsubj,len(roi_labels),len(tasks)))*np.nan # [nvoxel,npos(s1),nsubj,nroi,ntask]
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        for subj_i in range(len(subjs)):
            stimposicond = stimposicond_all[task_i,subj_i,:]
            # beta for each position (trial-by-trial)
            beta = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
            beta_mean = np.zeros((nvoxel,npos))*np.nan
            for pos in range(npos):
                beta[:,:,pos] = beta_all[task_i,roi_i,subj_i,:,stimposicond==pos+1].T
                beta_mean[:,pos] = np.nanmean(beta[:,:,pos],axis=1)
                rvv_all[:,pos,subj_i,roi_i,task_i] = np.var(beta[:,:,pos],axis=1)
                rv_p_all[pos,subj_i,roi_i,task_i] = np.nanmedian(np.var(beta[:,:,pos],axis=1)) # 100
                
# concat data across position
rv_all = np.zeros((npos*nsubj,len(roi_labels),len(tasks)))*np.nan
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        c1 = np.array([])
        for subj_i in range(len(subjs)):
            c1 = np.append(c1,rv_p_all[:,subj_i,roi_i,task_i])
        rv_all[:,roi_i,task_i] = c1

np.savez('../expectedoutput/responsevariance',rv_p_all=rv_p_all,rv_all=rv_all,rvv_all=rvv_all)

# %% [markdown]
# #### 2.3 noise correlation

# %%
# calculate
corr_p_all = np.zeros((npos,nsubj,len(roi_labels),len(tasks))) # [npos(s1), nsubj,nroi,ntask]
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        for subj_i in range(len(subjs)):
            stimposicond = stimposicond_all[task_i,subj_i,:]
            # beta for each position (trial-by-trial)
            beta = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
            for pos in range(npos):
                beta[:,:,pos] = beta_all[task_i,roi_i,subj_i,:,stimposicond==pos+1].T
            for s1 in range(npos):
                c = np.triu(np.corrcoef(beta[:,:,s1]),1) # 100 x 100 # 取上三角(不包括对角)
                corr_p_all[s1,subj_i,roi_i,task_i] = np.nanmedian(c[c!=0])
                #corr_p_all[s1,subj_i,roi_i,task_i] = fisherztrans(np.nanmedian(c[c!=0]))  # Fisher Z transformation

# concat data across position
corr_all = np.zeros((npos*nsubj,len(roi_labels),len(tasks)))*np.nan
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        c = np.array([])
        for subj_i in range(len(subjs)):
            c = np.append(c,corr_p_all[:,subj_i,roi_i,task_i])
        corr_all[:,roi_i,task_i] = c

np.savez('../expectedoutput/corr',corr_p_all=corr_p_all,corr_all=corr_all)

# %% [markdown]
# ### 3 LFI

# %% [markdown]
# #### 3.1 I_bc

# %%
def cal_lfi(beta_mean_cond,beta_cond,s1,s2,log=False):
    # ds
    dr = s1//4-s2//4
    dc = s1%4-s2%4
    ds = ds0 *  (dr**2+dc**2)**0.5
    # df & |dfnorm|
    df = np.mat(beta_mean_cond[:,s1] - beta_mean_cond[:,s2])
    dfnorm = np.linalg.norm(df,axis=1)
    # eigenvector & eigenvalue
    q1 = np.cov(beta_cond[:,:,s1])
    q2 = np.cov(beta_cond[:,:,s2])
    q = (q1 + q2)/2 # 100 x 100
    w,v = np.linalg.eigh(q)
    ullambda = np.nanmean(w)
    htlambda = w/ullambda
    # lfi
    lfi = dfnorm**2/ullambda*np.nansum([(df/dfnorm@v[:,i])**2/htlambda[i] for i in range(len(htlambda))])/(ds)**2
    #lfi = df@np.linalg.inv(q)@df.T/(ds)**2
    if log:
        lfi = np.log(lfi)
    return lfi,ds

# %% [markdown]
# $$I=\frac{df^T*S^{-1}*df}{ds^2}$$
# $$\hat I_{bc}=I*\frac{2T-N-3}{2T-2}-\frac{2N}{Tds^2}$$
#
# $S$ is the empirical covariance for each presented stimulus:
# $$
# S_1 = \frac{1}{T-1} \displaystyle\sum^T(\bold r - \bold f)^T(\bold r - \bold f)
# $$

# %%
# calculate
LFI_bc_ij_all = np.zeros((npos,npos,nsubj,len(roi_labels),len(tasks))) # [npos(s1),npos(s2),nsubj,nroi,ntask]
LFI_ij_all = np.zeros((npos,npos,nsubj,len(roi_labels),len(tasks))) # [npos(s1),npos(s2),nsubj,nroi,ntask]
logLFI_bc_ij_all = np.zeros((npos,npos,nsubj,len(roi_labels),len(tasks))) # [npos(s1),npos(s2),nsubj,nroi,ntask]
logLFI_ij_all = np.zeros((npos,npos,nsubj,len(roi_labels),len(tasks))) # [npos(s1),npos(s2),nsubj,nroi,ntask]
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        for subj_i in range(len(subjs)):
            stimposicond = stimposicond_all[task_i,subj_i,:]
            # beta for each position (trial-by-trial)
            beta = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
            beta_mean = np.zeros((nvoxel,npos))*np.nan
            for pos in range(npos):
                beta[:,:,pos] = beta_all[task_i,roi_i,subj_i,:,stimposicond==pos+1].T
                beta_mean[:,pos] = np.nanmean(beta[:,:,pos],axis=1)
            for s1 in range(npos-1):
                for s2 in range(s1+1,npos):
                    [LFI_ij,ds] = cal_lfi(beta_mean,beta,s1,s2)
                    LFI_bc_ij = LFI_ij*(2*ntrialperpos-nvoxel-3)/(2*ntrialperpos-2)-(2*nvoxel)/(ntrialperpos*(ds)**2)
                    LFI_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,task_i] = LFI_ij
                    LFI_bc_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,task_i] = LFI_bc_ij
                    logLFI_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,task_i] = np.log(LFI_ij)
                    logLFI_bc_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,task_i] = np.log(LFI_bc_ij)

                    
# concat reuslts by distance
LFI_bc_d = np.zeros((len(d),nsample,len(roi_labels),len(tasks)))*np.nan # d x sample x roi x task
LFI_d = np.zeros((len(d),nsample,len(roi_labels),len(tasks)))*np.nan # d x sample x roi x task
logLFI_bc_d = np.zeros((len(d),nsample,len(roi_labels),len(tasks)))*np.nan # d x sample x roi x task
logLFI_d = np.zeros((len(d),nsample,len(roi_labels),len(tasks)))*np.nan # d x sample x roi x task
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        for dd in range(len(d)):
            LFI_bc_dd = np.array([])
            LFI_dd = np.array([])
            logLFI_bc_dd = np.array([])
            logLFI_dd = np.array([])
            for subj_i in range(len(subjs)):
                LFI_bc_dd = np.append(LFI_bc_dd,LFI_bc_ij_all[ds_list==d[dd],subj_i,roi_i,task_i])
                LFI_dd = np.append(LFI_dd,LFI_ij_all[ds_list==d[dd],subj_i,roi_i,task_i])
                logLFI_bc_dd = np.append(logLFI_bc_dd,logLFI_bc_ij_all[ds_list==d[dd],subj_i,roi_i,task_i])
                logLFI_dd = np.append(logLFI_dd,logLFI_ij_all[ds_list==d[dd],subj_i,roi_i,task_i])
            LFI_bc_d[dd,0:len(LFI_bc_dd),roi_i,task_i] = LFI_bc_dd
            LFI_d[dd,0:len(LFI_bc_dd),roi_i,task_i] = LFI_dd
            logLFI_bc_d[dd,0:len(LFI_bc_dd),roi_i,task_i] = logLFI_bc_dd
            logLFI_d[dd,0:len(LFI_bc_dd),roi_i,task_i] = logLFI_dd

# average LFI across position pairs for each distance for each subject
LFI_bc_d_subj = np.zeros((len(d),nsubj,len(roi_labels),len(tasks)))*np.nan # d x subj x roi x task
for dd in range(len(d)):
    LFI_bc_d_subj[dd,:,:,:] = np.nanmean(LFI_bc_ij_all[ds_list==d[dd],:,:,:],axis=0)
LFI_d_subj = np.zeros((len(d),nsubj,len(roi_labels),len(tasks)))*np.nan # d x subj x roi x task
for dd in range(len(d)):
    LFI_d_subj[dd,:,:,:] = np.nanmean(LFI_ij_all[ds_list==d[dd],:,:,:],axis=0)
logLFI_bc_d_subj = np.zeros((len(d),nsubj,len(roi_labels),len(tasks)))*np.nan # d x subj x roi x task
for dd in range(len(d)):
    logLFI_bc_d_subj[dd,:,:,:] = np.nanmean(logLFI_bc_ij_all[ds_list==d[dd],:,:,:],axis=0)
logLFI_d_subj = np.zeros((len(d),nsubj,len(roi_labels),len(tasks)))*np.nan # d x subj x roi x task
for dd in range(len(d)):
    logLFI_d_subj[dd,:,:,:] = np.nanmean(logLFI_ij_all[ds_list==d[dd],:,:,:],axis=0)


np.savez('../expectedoutput/LFI_bc',LFI_bc_ij_all=LFI_bc_ij_all,LFI_bc_d=LFI_bc_d,LFI_bc_d_subj=LFI_bc_d_subj,
         LFI_ij_all=LFI_ij_all,LFI_d=LFI_d,LFI_d_subj=LFI_d_subj,
         logLFI_bc_ij_all=logLFI_bc_ij_all,logLFI_bc_d=logLFI_bc_d,logLFI_bc_d_subj=logLFI_bc_d_subj,
         logLFI_ij_all=logLFI_ij_all,logLFI_d=logLFI_d,logLFI_d_subj=logLFI_d_subj)

# %% [markdown]
# #### 3.2 |df|

# %%
# calculate
dfnorm_ij_all = np.zeros((npos,npos,nsubj,len(roi_labels),len(tasks))) # [npos(s1),npos(s2),nsubj,nroi,ntask]
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        for subj_i in range(len(subjs)):
            stimposicond = stimposicond_all[task_i,subj_i,:]
            # beta_sel_glmr2
            beta_mean = np.zeros((nvoxel,npos))*np.nan
            for pos in range(npos):
                beta_mean[:,pos] = np.nanmean(beta_all[task_i,roi_i,subj_i,:,stimposicond==pos+1].T,axis=1)
            for s1 in range(npos):
                dfnorm_ij_all[s1,:,subj_i,roi_i,task_i] = np.linalg.norm(beta_mean[:,s1] - beta_mean.T,axis=1)

# concat reuslts by distance
dfnorm_d = np.zeros((len(d),nsample,len(roi_labels),len(tasks)))*np.nan # d x sample x roi x task
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        for dd in range(len(d)):
            dfnorm_dd = np.array([])
            for subj_i in range(len(subjs)):
                dfnorm_dd = np.append(dfnorm_dd,dfnorm_ij_all[ds_list==d[dd],subj_i,roi_i,task_i])
            dfnorm_d[dd,0:len(dfnorm_dd),roi_i,task_i] = dfnorm_dd

# average dfnorm across position pairs for each distance for each subject
dfnorm_d_subj = np.zeros((len(d),nsubj,len(roi_labels),len(tasks)))*np.nan # d x subj x roi x task
for dd in range(len(d)):
    dfnorm_d_subj[dd,:,:,:] = np.nanmean(dfnorm_ij_all[ds_list==d[dd],:,:,:],axis=0)
        
np.savez('../expectedoutput/dfnorm',dfnorm_ij_all=dfnorm_ij_all,dfnorm_d=dfnorm_d,dfnorm_d_subj=dfnorm_d_subj)

# %% [markdown]
# #### 3.3 mean variance

# %%
# calculate
v_ij_all = np.zeros((npos,npos,nsubj,len(roi_labels),len(tasks)))*np.nan # [npos,nsubj,nroi,ntask]
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        for subj_i in range(len(subjs)): #[0,1,2,4,5,6,7]:#
            stimposicond = stimposicond_all[task_i,subj_i,:]
            # beta for each position (trial-by-trial)
            beta = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
            beta_mean = np.zeros((nvoxel,npos))*np.nan
            for pos in range(npos):
                beta[:,:,pos] = beta_all[task_i,roi_i,subj_i,:,stimposicond==pos+1].T
                beta_mean[:,pos] = np.nanmean(beta[:,:,pos],axis=1)
            for s1 in range(npos):
                for s2 in range(s1,npos):
                    # eigenvector & eigenvalue
                    q1 = np.cov(beta[:,:,s1])
                    q2 = np.cov(beta[:,:,s2])
                    q = (q1 + q2)/2 # 100 x 100
                    '''
                    if np.isnan(q).any():
                        q=np.array(q)
                        q=q[~np.isnan(q).all(axis=1)]
                        q=q[:,~np.isnan(q).all(axis=0)]
                        q=np.mat(q)
                    '''
                    w,v = np.linalg.eigh(q)
                    ullambda = np.nanmean(w)
                    v_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,task_i] = ullambda
                
# concat results by distance
v_d = np.zeros((len(d),nsample,len(roi_labels),len(tasks)))*np.nan # d x sample x roi x task
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        for dd in range(len(d)):
            v_dd = np.array([])
            for subj_i in range(len(subjs)):
                v_dd = np.append(v_dd,v_ij_all[ds_list==d[dd],subj_i,roi_i,task_i])
            v_d[dd,0:len(v_dd),roi_i,task_i] = v_dd

# average meanvariance across position pairs for each distance for each subject
v_d_subj = np.zeros((len(d),nsubj,len(roi_labels),len(tasks)))*np.nan # d x subj x roi x task
for dd in range(len(d)):
    v_d_subj[dd,:,:,:] = np.mean(v_ij_all[ds_list==d[dd],:,:,:],axis=0)

np.savez('../expectedoutput/meanvariance',v_ij_all=v_ij_all,v_d=v_d,v_d_subj=v_d_subj)

# %% [markdown]
# #### 3.002 sn

# %% [markdown]
# $$
# \frac{(\xi_i\cdot \hat{df})^2}{\hat\lambda_i}
# $$

# %%
# calculate
sn_ij_all = np.zeros((nvoxel,npos,npos,nsubj,len(roi_labels),len(tasks)))*np.nan # [npc,npos(s1),npos(s2),nsubj,nroi,ntask]

for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        for subj_i in range(len(subjs)):
            stimposicond = stimposicond_all[task_i,subj_i,:]
            # beta for each position (trial-by-trial)
            beta = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
            beta_mean = np.zeros((nvoxel,npos))*np.nan
            for pos in range(npos):
                beta[:,:,pos] = beta_all[task_i,roi_i,subj_i,:,stimposicond==pos+1].T
                beta_mean[:,pos] = np.nanmean(beta[:,:,pos],axis=1)
            for s1 in range(npos):
                for s2 in range(s1+1,npos):
                    # eigenvector & eigenvalue
                    q1 = np.cov(beta[:,:,s1])
                    q2 = np.cov(beta[:,:,s2])
                    q = (q1 + q2)/2 # 100 x 100
                    w,v = np.linalg.eigh(q)
                    u = np.nanmean(w)
                    df = beta_mean[:,s1] - beta_mean[:,s2]
                    for i in range(nvoxel):
                        dotproduct = np.dot(df,v[:,nvoxel-i-1]) # descend
                        df_norm = np.linalg.norm(df)
                        sn_ij_all[i,[s1,s2],[s2,s1],subj_i,roi_i,task_i] = (dotproduct/df_norm)**2/(w[nvoxel-i-1]/u)

# cumulative
sncum_ij_all = np.zeros((nvoxel,npos,npos,nsubj,len(roi_labels),len(tasks)))*np.nan # [npc,npos(s1),npos(s2),nsubj,nroi,ntask]
for ipc in range(nvoxel):
    sncum_ij_all[ipc,:,:,:,:,:] = sn_ij_all[:ipc+1,:,:,:,:,:].sum(axis=0)

# sum
snsum_ij_all = sn_ij_all.sum(axis=0)

# concat results by distance
sn_d = np.zeros((nvoxel,len(d),nsample,len(roi_labels),len(tasks)))*np.nan # npc x d x sample x roi
sncum_d = np.zeros((nvoxel,len(d),nsample,len(roi_labels),len(tasks)))*np.nan # npc x d x sample x roi
snsum_d = np.zeros((len(d),nsample,len(roi_labels),len(tasks)))*np.nan # d x sample x roi
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        for dd in range(len(d)):
            sn_dd = np.empty((nvoxel,0))
            sncum_dd = np.empty((nvoxel,0))
            snsum_dd = np.empty((0))
            for subj_i in range(len(subjs)):
                sn_dd = np.append(sn_dd,sn_ij_all[:,ds_list==d[dd],subj_i,roi_i,task_i],axis=1)
                sncum_dd = np.append(sncum_dd,sncum_ij_all[:,ds_list==d[dd],subj_i,roi_i,task_i],axis=1)
                snsum_dd = np.append(snsum_dd,snsum_ij_all[ds_list==d[dd],subj_i,roi_i,task_i])
            sn_d[:,dd,0:sn_dd.shape[1],roi_i,task_i] = sn_dd
            sncum_d[:,dd,0:sn_dd.shape[1],roi_i,task_i] = sncum_dd
            snsum_d[dd,0:sn_dd.shape[1],roi_i,task_i] = snsum_dd

# average sn across position pairs for each distance for each subject
sn_d_subj = np.zeros((nvoxel,len(d),nsubj,len(roi_labels),len(tasks)))*np.nan # npc x d x subj x roi x task
for dd in range(len(d)):
    sn_d_subj[:,dd,:,:,:] = np.nanmean(sn_ij_all[:,ds_list==d[dd],:,:,:],axis=1)

# average sn across position pairs for each distance for each subject
sncum_d_subj = np.zeros((nvoxel,len(d),nsubj,len(roi_labels),len(tasks)))*np.nan # npc x d x subj x roi x task
for dd in range(len(d)):
    sncum_d_subj[:,dd,:,:,:] = np.nanmean(sncum_ij_all[:,ds_list==d[dd],:,:,:],axis=1)

# average sn across position pairs for each distance for each subject
snsum_d_subj = np.zeros((len(d),nsubj,len(roi_labels),len(tasks)))*np.nan # d x subj x roi x task
for dd in range(len(d)):
    snsum_d_subj[dd,:,:,:] = np.nanmean(snsum_ij_all[ds_list==d[dd],:,:,:],axis=0)

np.savez('../expectedoutput/sn',sn_ij_all=sn_ij_all,sn_d=sn_d,sn_d_subj=sn_d_subj,
         sncum_ij_all=sncum_ij_all,sncum_d=sncum_d,sncum_d_subj=sncum_d_subj,
         snsum_ij_all=snsum_ij_all,snsum_d=snsum_d,snsum_d_subj=snsum_d_subj,)

# %%
'''
r = np.load('../expectedoutput/sn.npz',allow_pickle=True)
sn_ij_all = r['sn_ij_all']
sn_d = r['sn_d']
sn_d_subj = r['sn_d_subj']
sncum_ij_all = r['sncum_ij_all']
sncum_d = r['sncum_d']
sncum_d_subj = r['sncum_d_subj']
snsum_ij_all = r['snsum_ij_all']
snsum_d = r['snsum_d']
snsum_d_subj = r['snsum_d_subj']
'''

# %% [markdown]
# #### 3.4 signal rotation angle

# %% [markdown]
# $$
# \theta = arccos(\frac{a b}{|a||b|})
# $$

# %%
# calculate
srangle_ij_all = np.zeros((npos,npos,nsubj,len(roi_labels)))*np.nan # [npos(s1),npos(s2),nsubj,nroi]
for roi_i in range(len(roi_labels)):
    for subj_i in range(len(subjs)):
        stimposicond_face = stimposicond_all[0,subj_i,:]
        stimposicond_fix = stimposicond_all[1,subj_i,:]
        # beta for each position (trial-    by-trial)
        beta_face = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
        beta_fix = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
        beta_mean_face = np.zeros((nvoxel,npos))*np.nan
        beta_mean_fix = np.zeros((nvoxel,npos))*np.nan
        for pos in range(npos):
            beta_face[:,:,pos] = beta_all[0,roi_i,subj_i,:,stimposicond_face==pos+1].T
            beta_fix[:,:,pos] = beta_all[1,roi_i,subj_i,:,stimposicond_face==pos+1].T
            beta_mean_face[:,pos] = np.nanmean(beta_face[:,:,pos],axis=1)
            beta_mean_fix[:,pos] = np.nanmean(beta_fix[:,:,pos],axis=1)
        for s1 in range(npos-1):
            for s2 in range(s1,npos):
                df_face = beta_mean_face[:,s1]-beta_mean_face[:,s2]
                df_fix = beta_mean_fix[:,s1]-beta_mean_fix[:,s2]
                df_dotproduct = np.dot(df_face,df_fix)
                df_norm_face = np.linalg.norm(df_face)
                df_norm_fix = np.linalg.norm(df_fix)
                rot_deg = np.degrees(np.arccos(df_dotproduct/(df_norm_face*df_norm_fix)))
                srangle_ij_all[[s1,s2],[s2,s1],subj_i,roi_i] = rot_deg

# concat results by distance
srangle_d = np.zeros((len(d),nsample,len(roi_labels)))*np.nan # d x sample x roi
for roi_i in range(len(roi_labels)):
    for dd in range(len(d)):
        srangle_dd = np.array([])
        for subj_i in range(len(subjs)):
            srangle_dd = np.append(srangle_dd,srangle_ij_all[ds_list==d[dd],subj_i,roi_i])
        srangle_d[dd,0:len(srangle_dd),roi_i] = srangle_dd

# average srangle across position pairs for each distance for each subject
srangle_d_subj = np.zeros((len(d),nsubj,len(roi_labels)))*np.nan # d x subj x roi
for dd in range(len(d)):
    srangle_d_subj[dd,:,:] = np.nanmean(srangle_ij_all[ds_list==d[dd],:,:],axis=0)
    

np.savez('../expectedoutput/srangle',srangle_ij_all=srangle_ij_all,srangle_d=srangle_d,srangle_d_subj=srangle_d_subj)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_48924\2402930271.py:24: RuntimeWarning: invalid value encountered in scalar divide
#   rot_deg = np.degrees(np.arccos(df_dotproduct/(df_norm_face*df_norm_fix)))

# %%
# split dataset
split_num = 2
beta_split = np.array(np.split(beta_all,split_num,axis=-1)) # split x task x roi x subj x voxel x trial/split
stimposicond_split = np.array(np.split(stimposicond_all,split_num,axis=-1)) # split x task x subj x trial/split

srangle_ctl = np.empty((len(tasks),len(d),nsubj,len(roi_labels))) # task x 9 x subj x roi
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        for subj_i in range(nsubj):
            beta = beta_split[:,task_i,roi_i,subj_i,:,:] # split x voxel x trial/split
            stimposicond = stimposicond_split[:,task_i,subj_i,:] # split x trial/split
            for d_i in range(len(d)):
                d_pair = np.array(np.where(ds_list == d[d_i]))
                srangle_d = []
                for d_j in range(d_pair.shape[1]):
                    df0 = np.nanmean(beta[0,:,stimposicond[0]==d_pair[0,d_j]].T,axis=-1) - np.nanmean(beta[0,:,stimposicond[0]==d_pair[1,d_j]].T,axis=-1)
                    df1 = np.nanmean(beta[1,:,stimposicond[1]==d_pair[0,d_j]].T,axis=-1) - np.nanmean(beta[1,:,stimposicond[1]==d_pair[1,d_j]].T,axis=-1)
                    df_dotproduct = np.dot(df0,df1)
                    df0_norm = np.linalg.norm(df0)
                    df1_norm = np.linalg.norm(df1)
                    rot_deg = np.degrees(np.arccos(df_dotproduct/(df0_norm*df1_norm)))
                    srangle_d.append(rot_deg)
                srangle_ctl[task_i,d_i,subj_i,roi_i] = np.nanmean(srangle_d)

np.savez('../expectedoutput/srangle_ctl.npz',srangle_ctl = srangle_ctl)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_52028\2034766569.py:16: RuntimeWarning: Mean of empty slice
#   df0 = np.nanmean(beta[0,:,stimposicond[0]==d_pair[0,d_j]].T,axis=-1) - np.nanmean(beta[0,:,stimposicond[0]==d_pair[1,d_j]].T,axis=-1)
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_52028\2034766569.py:17: RuntimeWarning: Mean of empty slice
#   df1 = np.nanmean(beta[1,:,stimposicond[1]==d_pair[0,d_j]].T,axis=-1) - np.nanmean(beta[1,:,stimposicond[1]==d_pair[1,d_j]].T,axis=-1)

# %% [markdown]
# #### 3.5 PC rotation angle & variance

# %%
# calculate
pcv_ij_all = np.zeros((nvoxel,npos,npos,nsubj,len(roi_labels),len(tasks)))*np.nan # [npc,npos,npos,nsubj,nroi,ntask]
pcvi_ij_all = np.zeros((nvoxel,npos,npos,nsubj,len(roi_labels),len(tasks)))*np.nan # [npc,npos,npos,nsubj,nroi,ntask]
vec_ij_all = np.zeros((nvoxel,nvoxel,npos,npos,nsubj,len(roi_labels),len(tasks)))*np.nan # [eigenvector,npc,npos,npos,nsubj,nroi,ntask]
cwangle_ij_all = np.zeros((nvoxel,npos,npos,nsubj,len(roi_labels)))*np.nan # [npc,npos,npos,nsubj,nroi]
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        for subj_i in range(len(subjs)):
            stimposicond = stimposicond_all[task_i,subj_i,:]
            # beta for each position (trial-by-trial)
            beta = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
            beta_mean = np.zeros((nvoxel,npos))*np.nan
            for pos in range(npos):
                beta[:,:,pos] = beta_all[task_i,roi_i,subj_i,:,stimposicond==pos+1].T
                beta_mean[:,pos] = np.nanmean(beta[:,:,pos],axis=1)
            for s1 in range(npos):
                for s2 in range(s1+1,npos):
                    # eigenvector & eigenvalue
                    q1 = np.cov(beta[:,:,s1])
                    q2 = np.cov(beta[:,:,s2])
                    q = (q1 + q2)/2 # 100 x 100

                    w,v = np.linalg.eigh(q)
                    sorted_res = sorted(enumerate(w), key=lambda x: x[1],reverse=True)
                    sorted_w = [x[1] for x in sorted_res]
                    sorted_n = [x[0] for x in sorted_res]
                    pcv_ij_all[:len(sorted_w),s1,s2,subj_i,roi_i,task_i] = sorted_w
                    pcv_ij_all[:len(sorted_w),s2,s1,subj_i,roi_i,task_i] = sorted_w
                    pcvi_ij_all[:len(sorted_w),s1,s2,subj_i,roi_i,task_i] = sorted_w/np.nanmean(w)
                    pcvi_ij_all[:len(sorted_w),s2,s1,subj_i,roi_i,task_i] = sorted_w/np.nanmean(w)
                    vec_ij_all[:len(sorted_w),:len(sorted_w),s1,s2,subj_i,roi_i,task_i] = v[:,sorted_n]
                    vec_ij_all[:len(sorted_w),:len(sorted_w),s2,s1,subj_i,roi_i,task_i] = v[:,sorted_n]

for roi_i in range(len(roi_labels)):
    for subj_i in range(len(subjs)):
        for s1 in range(npos-1):
            for s2 in range(s1+1,npos):
                for npc in range(nvoxel):
                    ev_face = vec_ij_all[:,npc,s1,s2,subj_i,roi_i,0]
                    ev_fix = vec_ij_all[:,npc,s1,s2,subj_i,roi_i,1]
                    ev_dotproduct = np.dot(ev_face,ev_fix)
                    ev_norm_face = np.linalg.norm(ev_face)
                    ev_norm_fix = np.linalg.norm(ev_fix)
                    crot_deg = np.degrees(np.arccos(ev_dotproduct/(ev_norm_face*ev_norm_fix)))
                    cwangle_ij_all[npc,[s1,s2],[s2,s1],subj_i,roi_i] = crot_deg if crot_deg<90 else 180-crot_deg
                    #cwangle_ij_all[npc,[s1,s2],[s2,s1],subj_i,roi_i] = crot_deg

# concat results by distance
cwangle_d = np.zeros((nvoxel,len(d),nsample,len(roi_labels)))*np.nan # pc x d x sample x roi
for roi_i in range(len(roi_labels)):
    for dd in range(len(d)):
        cwangle_dd = np.empty((nvoxel,0))
        for subj_i in range(len(subjs)):
            cwangle_dd = np.append(cwangle_dd,cwangle_ij_all[:,ds_list==d[dd],subj_i,roi_i],axis=1)
        cwangle_d[:,dd,0:cwangle_dd.shape[1],roi_i] = cwangle_dd

pcv_d = np.zeros((nvoxel,len(d),nsample,len(roi_labels),len(tasks)))*np.nan # pc x d x sample x roi
pcvi_d = np.zeros((nvoxel,len(d),nsample,len(roi_labels),len(tasks)))*np.nan # pc x d x sample x roi
for task_i in range(2):
    for roi_i in range(len(roi_labels)):
        for dd in range(len(d)):
            pcv_dd = np.empty((nvoxel,0))
            pcvi_dd = np.empty((nvoxel,0))
            for subj_i in range(len(subjs)):
                pcv_dd = np.append(pcv_dd,pcv_ij_all[:,ds_list==d[dd],subj_i,roi_i,task_i],axis=1)
                pcvi_dd = np.append(pcvi_dd,pcvi_ij_all[:,ds_list==d[dd],subj_i,roi_i,task_i],axis=1)
            pcv_d[:,dd,0:pcv_dd.shape[1],roi_i,task_i] = pcv_dd
            pcvi_d[:,dd,0:pcvi_dd.shape[1],roi_i,task_i] = pcvi_dd


# average data across position pairs for each distance for each subject
pcv_d_subj = np.zeros((nvoxel,len(d),nsubj,len(roi_labels),len(tasks)))*np.nan # npc x d x subj x roi x task
pcvi_d_subj = np.zeros((nvoxel,len(d),nsubj,len(roi_labels),len(tasks)))*np.nan
cwangle_d_subj = np.zeros((nvoxel,len(d),nsubj,len(roi_labels)))*np.nan # npc x d x subj x roi
for dd in range(len(d)):
    pcv_d_subj[:,dd,:,:,:] = np.nanmean(pcv_ij_all[:,ds_list==d[dd],:,:,:],axis=1)
    pcvi_d_subj[:,dd,:,:,:] = np.nanmean(pcvi_ij_all[:,ds_list==d[dd],:,:,:],axis=1)
    cwangle_d_subj[:,dd,:,:] = np.nanmean(cwangle_ij_all[:,ds_list==d[dd],:,:],axis=1)

np.savez('../expectedoutput/cwangle',pcv_ij_all=pcv_ij_all,cwangle_ij_all=cwangle_ij_all,cwangle_d=cwangle_d,pcv_d=pcv_d,
         pcvi_d=pcvi_d,pcvi_ij_all=pcvi_ij_all,
         pcv_d_subj=pcv_d_subj,pcvi_d_subj=pcvi_d_subj,cwangle_d_subj=cwangle_d_subj)

# %% [markdown]
# ### 4 LFI: four mechanisms

# %%
def cal_lfi_param(beta_mean_cond,beta_cond,s1,s2):
    # ds
    dr = s1//4-s2//4
    dc = s1%4-s2%4
    ds = ds0 *  (dr**2+dc**2)**0.5
    # df & |dfnorm|
    df = np.mat(beta_mean_cond[:,s1] - beta_mean_cond[:,s2])

    dfnorm = np.linalg.norm(df,axis=1)
    # eigenvector & eigenvalue
    q1 = np.cov(beta_cond[:,:,s1])
    q2 = np.cov(beta_cond[:,:,s2])
    q = (q1 + q2)/2 # 100 x 100

    w,v = np.linalg.eigh(q)
    ullambda = np.nanmean(w)
    htlambda = w/ullambda
    return ds,df,dfnorm,v,ullambda,htlambda

def cal_lfi(ds,dfnorm,ullambda,df_dfnorm,v,htlambda,bc=True,ntrialperpos=ntrialperpos, nvoxel=nvoxel):
    I = 1/(ds)**2*dfnorm**2/ullambda*np.nansum([(df_dfnorm@v[:,i])**2/htlambda[i] for i in range(len(htlambda))])
    if bc:
        I_bc = I*(2*ntrialperpos-nvoxel-3)/(2*ntrialperpos-2)-(2*nvoxel)/(ntrialperpos*(ds)**2)
        return I_bc
    else:
        return I

def cal_lfi_log(ds,dfnorm,ullambda,df_dfnorm,v,htlambda,bc=True,ntrialperpos=ntrialperpos, nvoxel=nvoxel):
    I = cal_lfi(ds,dfnorm,ullambda,df_dfnorm,v,htlambda,bc,ntrialperpos, nvoxel)
    return np.log(I)

# %%
# calculate
Ilog_stw_ij_all = np.zeros((npos,npos,nsubj,len(roi_labels),5))*np.nan # [npos(s1),npos(s2),nsubj,nroi,ntype]
for roi_i in range(len(roi_labels)):
    for subj_i in range(len(subjs)):
        stimposicond_unatt = stimposicond_all[1,subj_i,:]
        stimposicond_att = stimposicond_all[0,subj_i,:]
        # beta for each position (trial-by-trial)
        beta_digit_all = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
        beta_digit_mean_all = np.zeros((nvoxel,npos))*np.nan
        beta_face_all = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
        beta_face_mean_all = np.zeros((nvoxel,npos))*np.nan
        for pos in range(npos):
            beta_digit_all[:,:,pos] = beta_all[1,roi_i,subj_i,:,stimposicond_unatt==pos+1].T
            beta_digit_mean_all[:,pos] = np.nanmean(beta_digit_all[:,:,pos],axis=1)
            beta_face_all[:,:,pos] = beta_all[0,roi_i,subj_i,:,stimposicond_att==pos+1].T
            beta_face_mean_all[:,pos] = np.nanmean(beta_face_all[:,:,pos],axis=1)
        for s1 in range(npos-1):
            for s2 in range(s1+1,npos):
                ds,df_digit,dfnorm_digit,v_digit,ullambda_digit,htlambda_digit = cal_lfi_param(beta_digit_mean_all,beta_digit_all,s1,s2)
                ds,df_face,dfnorm_face,v_face,ullambda_face,htlambda_face = cal_lfi_param(beta_face_mean_all,beta_face_all,s1,s2)
                # I_digit   I_se    I_ms I_sr,mw  I_face
                Ilog_stw_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,0] = cal_lfi_log(ds,dfnorm_digit,ullambda_digit,df_digit/dfnorm_digit,v_digit,htlambda_digit,bc=False)
                Ilog_stw_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,1] = cal_lfi_log(ds,dfnorm_face,ullambda_digit,df_digit/dfnorm_digit,v_digit,htlambda_digit,bc=False)
                Ilog_stw_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,2] = cal_lfi_log(ds,dfnorm_digit,ullambda_face,df_digit/dfnorm_digit,v_digit,htlambda_digit,bc=False)
                Ilog_stw_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,3] = cal_lfi_log(ds,dfnorm_digit,ullambda_digit,df_face/dfnorm_face,v_face,htlambda_face,bc=False)
                Ilog_stw_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,4] = cal_lfi_log(ds,dfnorm_face,ullambda_face,df_face/dfnorm_face,v_face,htlambda_face,bc=False)

i_types = ['digit','se','ms','srmw','face']
# concat reuslts by distance
Ilog_stw_d = np.zeros((len(d),nsample,len(roi_labels),5))*np.nan # d x sample x roi x type
for roi_i in range(len(roi_labels)):
    for dd in range(len(d)):
        Ilog = {'digit':np.array([]),'se':np.array([]),'ms':np.array([]),'srmw':np.array([]),'face':np.array([])}
        for subj_i in range(len(subjs)):
            for i in range(5):
                Ilog[i_types[i]] = np.append(Ilog[i_types[i]],Ilog_stw_ij_all[ds_list==d[dd],subj_i,roi_i,i])
                Ilog_stw_d[dd,0:len(Ilog[i_types[i]]),roi_i,i] = Ilog[i_types[i]]

deltaIlog_stw_d = Ilog_stw_d[:,:,:,1:]-Ilog_stw_d[:,:,:,[0]] # d x sample x roi x type

Ilog_stw_d_subj = np.zeros((len(d),nsubj,len(roi_labels),5))*np.nan # d x subj x roi x task
for dd in range(len(d)):
    Ilog_stw_d_subj[dd,:,:,:] = np.nanmean(Ilog_stw_ij_all[ds_list==d[dd],:,:,:],axis=0)
deltaIlog_stw_d_subj = Ilog_stw_d_subj[:,:,:,1:]-Ilog_stw_d_subj[:,:,:,[0]]# d x subj x roi x type

np.savez('../expectedoutput/LFI_separate',Ilog_stw_d=Ilog_stw_d,Ilog_stw_ij_all=Ilog_stw_ij_all,deltaIlog_stw_d=deltaIlog_stw_d,
         Ilog_stw_d_subj=Ilog_stw_d_subj,deltaIlog_stw_d_subj=deltaIlog_stw_d_subj)

# %% [markdown]
# ### 5 other analysis (supplementary)

# %% [markdown]
# #### 5.1 signal & noise correlation

# %% [markdown]
# signal correlation

# %%
# signal corr
# calculate
signal_corr_all = np.zeros([math.comb(nvoxel,2),len(roi_labels),len(tasks),nsubj])*np.nan
for task_i in range(len(tasks)):
    for roi_i in range(len(roi_labels)):
        for subj_i in range(nsubj):
            stimposicond = stimposicond_all[task_i,subj_i,:]
            beta_mean = np.zeros((nvoxel,npos))*np.nan
            beta = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
            for pos in range(npos):
                beta_mean[:,pos] = np.nanmean(beta_all[task_i,roi_i,subj_i,:,stimposicond==pos+1].T,axis=1)
            sc = np.corrcoef(beta_mean[:,:]) # 100 x 100
            signal_corr_all[:,roi_i,task_i,subj_i] = sc[np.triu_indices(nvoxel,k=1)]
np.savez('../expectedoutput/sig_corr',signal_corr_all=signal_corr_all)

# %% [markdown]
# noise correlation

# %%
# calculate
noise_p_corr_all = np.zeros([npos,math.comb(nvoxel,2),len(roi_labels),len(tasks),nsubj])*np.nan
for subj_i in range(nsubj):
    for task_i in range(len(tasks)):
        for roi_i in range(len(roi_labels)):
            stimposicond = stimposicond_all[task_i,subj_i,:]
            beta_mean = np.zeros((nvoxel,npos))*np.nan
            beta = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
            for pos in range(npos):
                beta[:,:,pos] = beta_all[task_i,roi_i,subj_i,:,stimposicond==pos+1].T
                nc = np.corrcoef(beta[:,:,pos]) # 100 x 100
                noise_p_corr_all[pos,:,roi_i,task_i,subj_i] = nc[np.triu_indices(nvoxel,k=1)]
noise_corr_all = np.nanmedian(noise_p_corr_all,axis=0)
np.savez('../expectedoutput/noise_corr',noise_p_corr_all=noise_p_corr_all,noise_corr_all=noise_corr_all)

# %% [markdown]
# #### 5.2 shuffle correlation

# %%
def runlfi(pi,sfl_n,task_i,sfl_i,save=True):
    # sfl_type: 'ori' or 'sfld'
    LFI_bc_ij = np.full((sfl_n,npos,npos,nsubj,len(roi_labels)),np.nan) # [nshuffle,npos(s1),npos(s2),nsubj,nroi]
    for roi_i in range(len(roi_labels)):
        for subj_i in range(len(subjs)):
            print('pi{},roi{},subj{}'.format(pi,roi_i,subj_i))
            
            stimposicond0 = stimposicond_all[task_i,subj_i,:].copy() # trial
            beta0 = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
            for pos in range(npos):
                beta0[:,:,pos] = beta_all[task_i,roi_i,subj_i,:,stimposicond0==pos+1].T  
            
            # shuffle
            for i in tqdm(range(sfl_n)):
                if sfl_i == 0:

                    idx = np.array([np.random.permutation(ntrialperpos) for _ in range(npos)]).T
                    beta_sfl = np.take_along_axis(beta0, idx[None,:,:], axis=1) 
                elif sfl_i == 1:

                    idx = np.argsort(np.random.rand(nvoxel, ntrialperpos, npos), axis=1)
                    beta_sfl = np.take_along_axis(beta0, idx, axis=1)

                # bias-corrected LFI
                beta_sfl_mean = np.nanmean(beta_sfl,axis=1)

                for s1 in range(npos-1):
                    for s2 in range(s1+1,npos):
                        [LFI_ij,ds] = cal_lfi(beta_sfl_mean,beta_sfl,s1,s2)
                        LFI_bc = LFI_ij*(2*ntrialperpos-nvoxel-3)/(2*ntrialperpos-2)-(2*nvoxel)/(ntrialperpos*(ds)**2)
                        LFI_bc_ij[i,[s1,s2],[s2,s1],subj_i,roi_i] = LFI_bc
    return LFI_bc_ij

def parallel_lfi_shuffle(sfl_total,task_i,sfl_i,sfl_types,save=True):
    npall = 20
    sfl_n = int(sfl_total/npall)
    results = Parallel(n_jobs=-1)(delayed(runlfi)(
        pi=pi,
        sfl_n=sfl_n,
        task_i=task_i,
        sfl_i=sfl_i,
        save=save
        )
        for pi in range(npall))
    lfi_ij = np.concatenate(results, axis=0)

    # save                        
    if save: np.savez('../expectedoutput/lfi-bc_shuffle_'+sfl_types[sfl_i]+'_'+tasks[task_i],lfi_ij=lfi_ij)  

    return lfi_ij
  
def cal_lfi(beta_mean_cond,beta_cond,s1,s2,log=False):
    # ds
    dr = s1//4-s2//4
    dc = s1%4-s2%4
    ds = ds0 *  (dr**2+dc**2)**0.5
    # df & |dfnorm|
    df = beta_mean_cond[:,s1] - beta_mean_cond[:,s2]
    dfnorm = np.linalg.norm(df)
    # eigenvector & eigenvalue
    q1 = np.cov(beta_cond[:,:,s1])
    q2 = np.cov(beta_cond[:,:,s2])
    q = (q1 + q2)/2 # 100 x 100
    w,v = np.linalg.eigh(q)
    ullambda = np.nanmean(w)
    htlambda = w/ullambda
    # lfi
    proj = (df/dfnorm) @ v
    lfi = (dfnorm**2/ullambda) * np.nansum(np.square(proj)/ htlambda)/(ds**2)
    if log:
        lfi = np.log(lfi)
    return lfi,ds

# %%
import random 

# set
seed = 1234
np.random.seed(seed)
random.seed(seed)
sfl_total = 1000
sfl_types = ['ori','sfld']
task_idx = 1
sfl_idx = 1

# run 
lfi_ij = parallel_lfi_shuffle(sfl_total,task_i=task_idx,sfl_i=sfl_idx,sfl_types=sfl_types,save=True)

# %% [markdown]
# #### 5.2 estimation accuracy

# %%
from scipy.stats import multivariate_normal
from concurrent.futures import ThreadPoolExecutor, as_completed

def simulate_data(beta_all, stimposicond_all, ntrialperpos_sim = 80, rng=None):

    rng = np.random.default_rng() if rng is None else rng

    ntask,nroi,nsubj,nvoxel,_ = beta_all.shape

    ntrial_sim = ntrialperpos_sim * npos

    # generate stimposicond_sim_all
    stimposicond_sim = np.repeat(np.arange(1,npos+1),ntrialperpos_sim,)
    stimposicond_sim_all = np.tile(stimposicond_sim, (ntask,nsubj,1))
    
    beta_sim_all = np.full((ntask,nroi,nsubj,nvoxel,ntrial_sim), np.nan)

    for task_i in range(ntask):
        for roi_i in range(nroi):
            for subj_i in range(nsubj):
                beta_raw = beta_all[task_i,roi_i,subj_i]
                stim_raw = stimposicond_all[task_i,subj_i]

                stim_sim = stimposicond_sim_all[task_i,subj_i]
      
                for s in range(npos):
                    idx_raw = stim_raw == s + 1
                    X_raw = beta_raw[:, idx_raw]

                    mean0 = np.nanmean(X_raw, axis=1)
                    cov0 = np.cov(X_raw)
                    cov0 += np.eye(nvoxel) * 1e-6

                    idx_sim = stim_sim == s + 1

                    beta_sim_all[task_i,roi_i,subj_i,:,idx_sim] = rng.multivariate_normal(mean=mean0, cov=cov0, size=ntrialperpos_sim)
        
    return beta_sim_all, stimposicond_sim_all


def cal_lfi_param_cov(beta_mean_cond,beta_cov,s1,s2):
    # ds
    dr = s1//4-s2//4
    dc = s1%4-s2%4
    ds = ds0 *  (dr**2+dc**2)**0.5
    # df & |dfnorm|
    df = np.mat(beta_mean_cond[:,s1] - beta_mean_cond[:,s2])

    dfnorm = np.linalg.norm(df,axis=1)
    # eigenvector & eigenvalue
    q1 = beta_cov[:,:,s1]
    q2 = beta_cov[:,:,s2]
    q = (q1 + q2)/2 # 100 x 100

    w,v = np.linalg.eigh(q)
    ullambda = np.nanmean(w)
    htlambda = w/ullambda
    return ds,df,dfnorm,v,ullambda,htlambda

def cal_lfi(ds,dfnorm,ullambda,df_dfnorm,v,htlambda,bc=True,ntrialperpos=ntrialperpos, nvoxel=nvoxel):
    I = 1/(ds)**2*dfnorm**2/ullambda*np.nansum([(df_dfnorm@v[:,i])**2/htlambda[i] for i in range(len(htlambda))])
    if bc:
        return cal_lfi_bc(I, ntrialperpos, nvoxel, ds)
    else:
        return I

def cal_lfi_bc(I, ntrialperpos, nvoxel, ds):
    return I*(2*ntrialperpos-nvoxel-3)/(2*ntrialperpos-2)-(2*nvoxel)/(ntrialperpos*(ds)**2)

def cal_lfi_log_fast(ds,dfnorm,ullambda,df_dfnorm,v,htlambda,bc=True,ntrialperpos=ntrialperpos, nvoxel=nvoxel):
    projection = np.asarray(df_dfnorm) @ v
    I = (dfnorm*dfnorm / (ds * ds) / ullambda) * np.nansum(projection * projection / htlambda)
    #I = 1/(ds)**2*dfnorm**2/ullambda*np.nansum([(df_dfnorm@v[:,i])**2/htlambda[i] for i in range(len(htlambda))])
    if bc:
        I_bc = I*(2*ntrialperpos-nvoxel-3)/(2*ntrialperpos-2)-(2*nvoxel)/(ntrialperpos*(ds)**2)
        return np.log(I_bc)
    else:
        return np.log(I)

def cal_lfi_log(ds,dfnorm,ullambda,df_dfnorm,v,htlambda,bc=True,ntrialperpos=ntrialperpos, nvoxel=nvoxel):
    I = cal_lfi(ds,dfnorm,ullambda,df_dfnorm,v,htlambda,bc,ntrialperpos, nvoxel)
    return np.log(I)

def lfi_mechanism_task(beta_all,stimposicond_all):
    _,nroi,nsubj,nvoxel,ntrial = beta_all.shape
    ntrialperpos = int(ntrial/npos)
    Ilog_stw_ij_all = np.zeros((npos,npos,nsubj,len(roi_labels),5))*np.nan # [npos(s1),npos(s2),nsubj,nroi,ntype]
    I_stw_ij_all = np.zeros((npos,npos,nsubj,len(roi_labels),5))*np.nan # [npos(s1),npos(s2),nsubj,nroi,ntype]
    Ibc_stw_ij_all = np.zeros((npos,npos,nsubj,len(roi_labels),5))*np.nan # [npos(s1),npos(s2),nsubj,nroi,ntype]
    for roi_i in range(nroi):
        for subj_i in range(nsubj):
            stimposicond_unatt = stimposicond_all[1,subj_i,:]
            stimposicond_att = stimposicond_all[0,subj_i,:]
            # beta for each position (trial-by-trial)
            beta_digit_all = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
            beta_digit_mean_all = np.zeros((nvoxel,npos))*np.nan
            beta_face_all = np.zeros((nvoxel,ntrialperpos,npos))*np.nan # voxel x trial x position
            beta_face_mean_all = np.zeros((nvoxel,npos))*np.nan
            beta_digit_cov_all = np.zeros((nvoxel,nvoxel,npos))*np.nan # voxel x voxel x position
            beta_face_cov_all = np.zeros((nvoxel,nvoxel,npos))*np.nan
            for pos in range(npos):
                beta_digit_all[:,:,pos] = beta_all[1,roi_i,subj_i,:,stimposicond_unatt==pos + 1].T
                beta_digit_mean_all[:,pos] = np.nanmean(beta_digit_all[:,:,pos],axis=1)
                beta_face_all[:,:,pos] = beta_all[0,roi_i,subj_i,:,stimposicond_att==pos + 1].T
                beta_face_mean_all[:,pos] = np.nanmean(beta_face_all[:,:,pos],axis=1)
                beta_digit_cov_all[:,:,pos] = np.cov(beta_digit_all[:,:,pos])
                beta_face_cov_all[:,:,pos] = np.cov(beta_face_all[:,:,pos])
            for s1 in range(npos-1):
                for s2 in range(s1+1,npos):
                    ds,df_digit,dfnorm_digit,v_digit,ullambda_digit,htlambda_digit = cal_lfi_param_cov(beta_digit_mean_all,beta_digit_cov_all,s1,s2)
                    ds,df_face,dfnorm_face,v_face,ullambda_face,htlambda_face = cal_lfi_param_cov(beta_face_mean_all,beta_face_cov_all,s1,s2)
                    # I_digit   I_se    I_ms I_sr,mw  I_face

                    I_stw_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,0] = cal_lfi(ds,dfnorm_digit,ullambda_digit,df_digit/dfnorm_digit,v_digit,htlambda_digit,False,ntrialperpos, nvoxel)
                    I_stw_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,1] = cal_lfi(ds,dfnorm_face,ullambda_digit,df_digit/dfnorm_digit,v_digit,htlambda_digit,False,ntrialperpos, nvoxel)
                    I_stw_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,2] = cal_lfi(ds,dfnorm_digit,ullambda_face,df_digit/dfnorm_digit,v_digit,htlambda_digit,False,ntrialperpos, nvoxel)
                    I_stw_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,3] = cal_lfi(ds,dfnorm_digit,ullambda_digit,df_face/dfnorm_face,v_face,htlambda_face,False,ntrialperpos, nvoxel)
                    I_stw_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,4] = cal_lfi(ds,dfnorm_face,ullambda_face,df_face/dfnorm_face,v_face,htlambda_face,False,ntrialperpos, nvoxel)

                    Ibc_stw_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,:] = cal_lfi_bc(I_stw_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,:], ntrialperpos, nvoxel, ds)

    Ilog_stw_ij_all = np.log(I_stw_ij_all)

    deltaIlog_stw_ij_all = Ilog_stw_ij_all[...,1:]-Ilog_stw_ij_all[...,[0]]

    Ilog_stw_d_subj = np.zeros((len(d),nsubj,len(roi_labels),5))*np.nan # d x subj x roi x task
    for dd in range(len(d)):
        Ilog_stw_d_subj[dd,:,:,:] = np.nanmean(Ilog_stw_ij_all[ds_list==d[dd],:,:,:],axis=0)
    deltaIlog_stw_d_subj = Ilog_stw_d_subj[:,:,:,1:]-Ilog_stw_d_subj[:,:,:,[0]]# d x subj x roi x type

    I_stw_d_subj = np.zeros((len(d),nsubj,len(roi_labels),5))*np.nan # d x subj x roi x task
    for dd in range(len(d)):
        I_stw_d_subj[dd,:,:,:] = np.nanmean(I_stw_ij_all[ds_list==d[dd],:,:,:],axis=0)

    Ibc_stw_d_subj = np.zeros((len(d),nsubj,len(roi_labels),5))*np.nan # d x subj x roi x task
    for dd in range(len(d)):
        Ibc_stw_d_subj[dd,:,:,:] = np.nanmean(Ibc_stw_ij_all[ds_list==d[dd],:,:,:],axis=0)

    return Ilog_stw_ij_all,deltaIlog_stw_ij_all,I_stw_ij_all,Ibc_stw_ij_all,Ilog_stw_d_subj,deltaIlog_stw_d_subj,I_stw_d_subj,Ibc_stw_d_subj


def run_simanalysis_lfi_oneexp(beta_all, stimposicond_all, ntrialperpos_sim, seed=None,):
    
    #print(f"Simulating data (seed={seed}) ...")
    rng = np.random.default_rng(seed)
    # simulate data
    beta_sim_all,stimposicond_sim_all = simulate_data(beta_all, stimposicond_all, ntrialperpos_sim, rng=rng)

    #print('Analyzing data ...')
    # lfi, mechanisms
    _,_,_,_,Ilog_stw_d_subj,deltaIlog_stw_d_subj,I_stw_d_subj,Ibc_stw_d_subj = lfi_mechanism_task(beta_sim_all,stimposicond_sim_all)
    return {"Ilog_stw_d_subj":Ilog_stw_d_subj,
            "deltaIlog_stw_d_subj":deltaIlog_stw_d_subj,
            "I_stw_d_subj":I_stw_d_subj,
            "Ibc_stw_d_subj":Ibc_stw_d_subj}

def run_simanalysis_lfi(beta_all,stimposicond_all,ntrialperpos_sim,n_exp=200,n_jobs=None,seed=0,save=True,savefilename='../expectedoutput/trialest_lfi.npz'):
    print(f"Running {n_exp} simulations in parallel (threading) ...")

    if n_jobs is None:
        n_jobs = min(32, n_exp)

    seed_sequence = np.random.SeedSequence(seed)
    child_seeds = seed_sequence.spawn(n_exp)
    exp_seeds = [int(s.generate_state(1)[0]) for s in child_seeds]

    results = [None] * n_exp

    with ThreadPoolExecutor(max_workers=n_jobs) as executor:
        future_to_idx = {
            executor.submit(
                run_simanalysis_lfi_oneexp,
                beta_all,
                stimposicond_all,
                ntrialperpos_sim,
                exp_seeds[i],
            ): i
            for i in range(n_exp)
        }

        for future in as_completed(future_to_idx):
            i = future_to_idx[future]
            results[i] = future.result()
            print(f"Finished simulation {i + 1}/{n_exp}")

    output = {
        key: np.stack([result[key] for result in results], axis=0)
        for key in results[0]
    }

    if save:
        np.savez(savefilename, **output)
        print(f"Saved results to: {savefilename}")

    return output

# %%
np.load('../../plot_figures/data/trialest_lfi-80.npz',allow_pickle=True).keys()
# Out:
# KeysView(NpzFile '../../plot_figures/data/trialest_lfi-80.npz' with keys: deltaIlog_stw_d_subj, Ilog_stw_d_subj, Ibc_stw_d_subj, I_stw_d_subj)

# %%
# simulation and calculate LFI
for ntrialperpos_sim in [80, 160, 320, 640, 1280, 2560]:
    run_simanalysis_lfi(beta_all, stimposicond_all, ntrialperpos_sim=ntrialperpos_sim, 
            n_exp = 200, n_jobs = 4, save=True, savefilename='../expectedoutput/trialest_lfi-'+str(ntrialperpos_sim)+'.npz')
# Out:
# Running 200 simulations in parallel (threading) ...
# Finished simulation 4/200
# Finished simulation 5/200
# Finished simulation 3/200
# Finished simulation 6/200
# Finished simulation 2/200
# Finished simulation 7/200
# Finished simulation 10/200
# Finished simulation 1/200
# Finished simulation 8/200
# Finished simulation 9/200
# Finished simulation 11/200
# Finished simulation 12/200
# Finished simulation 14/200
# Finished simulation 13/200
# Finished simulation 15/200
# Finished simulation 16/200
# Finished simulation 18/200
# Finished simulation 17/200
# Finished simulation 20/200
# Finished simulation 19/200
# Finished simulation 21/200
# Finished simulation 22/200
# Finished simulation 23/200
# Finished simulation 24/200
# Finished simulation 25/200
# Finished simulation 26/200
# Finished simulation 27/200
# Finished simulation 28/200
# Finished simulation 29/200
# Finished simulation 30/200
# Finished simulation 31/200
# Finished simulation 32/200
# Finished simulation 33/200
# Finished simulation 34/200
# Finished simulation 35/200
# Finished simulation 36/200
# Finished simulation 37/200
# Finished simulation 38/200
# Finished simulation 39/200
# Finished simulation 40/200
# Finished simulation 41/200
# Finished simulation 42/200
# Finished simulation 44/200
# Finished simulation 43/200
# Finished simulation 45/200
# Finished simulation 52/200
# Finished simulation 51/200
# Finished simulation 46/200
# Finished simulation 48/200
# Finished simulation 47/200
# Finished simulation 49/200
# Finished simulation 50/200
# Finished simulation 54/200
# Finished simulation 53/200
# Finished simulation 55/200
# Finished simulation 56/200
# Finished simulation 57/200
# Finished simulation 58/200
# Finished simulation 60/200
# Finished simulation 59/200
# Finished simulation 61/200
# Finished simulation 62/200
# Finished simulation 63/200
# Finished simulation 64/200
# Finished simulation 65/200
# Finished simulation 66/200
# Finished simulation 67/200
# Finished simulation 68/200
# Finished simulation 69/200
# Finished simulation 70/200
# Finished simulation 71/200
# Finished simulation 72/200
# Finished simulation 73/200
# Finished simulation 74/200
# Finished simulation 75/200
# Finished simulation 76/200
# Finished simulation 77/200
# Finished simulation 84/200
# Finished simulation 79/200
# Finished simulation 78/200
# Finished simulation 83/200
# Finished simulation 80/200
# Finished simulation 81/200
# Finished simulation 82/200
# Finished simulation 87/200
# Finished simulation 86/200
# Finished simulation 85/200
# Finished simulation 88/200
# Finished simulation 95/200
# Finished simulation 91/200
# Finished simulation 96/200
# Finished simulation 90/200
# Finished simulation 89/200
# Finished simulation 92/200
# Finished simulation 93/200
# Finished simulation 94/200
# Finished simulation 97/200
# Finished simulation 98/200
# Finished simulation 99/200
# Finished simulation 101/200
# Finished simulation 100/200
# Finished simulation 102/200
# Finished simulation 103/200
# Finished simulation 104/200
# Finished simulation 105/200
# Finished simulation 106/200
# Finished simulation 107/200
# Finished simulation 109/200
# Finished simulation 110/200
# Finished simulation 108/200
# Finished simulation 111/200
# Finished simulation 112/200
# Finished simulation 113/200
# Finished simulation 114/200
# Finished simulation 117/200
# Finished simulation 115/200
# Finished simulation 116/200
# Finished simulation 118/200
# Finished simulation 119/200
# Finished simulation 120/200
# Finished simulation 121/200
# Finished simulation 122/200
# Finished simulation 124/200
# Finished simulation 123/200
# Finished simulation 125/200
# Finished simulation 126/200
# Finished simulation 127/200
# Finished simulation 128/200
# Finished simulation 129/200
# Finished simulation 130/200
# Finished simulation 131/200
# Finished simulation 135/200
# Finished simulation 132/200
# Finished simulation 133/200
# Finished simulation 134/200
# Finished simulation 139/200
# Finished simulation 138/200
# Finished simulation 140/200
# Finished simulation 137/200
# Finished simulation 136/200
# Finished simulation 141/200
# Finished simulation 142/200
# Finished simulation 143/200
# Finished simulation 144/200
# Finished simulation 145/200
# Finished simulation 146/200
# Finished simulation 147/200
# Finished simulation 148/200
# Finished simulation 150/200
# Finished simulation 151/200
# Finished simulation 149/200
# Finished simulation 152/200
# Finished simulation 153/200
# Finished simulation 156/200
# Finished simulation 154/200
# Finished simulation 157/200
# Finished simulation 155/200
# Finished simulation 158/200
# Finished simulation 160/200
# Finished simulation 159/200
# Finished simulation 161/200
# Finished simulation 162/200
# Finished simulation 164/200
# Finished simulation 166/200
# Finished simulation 165/200
# Finished simulation 163/200
# Finished simulation 168/200
# Finished simulation 167/200
# Finished simulation 169/200
# Finished simulation 170/200
# Finished simulation 172/200
# Finished simulation 171/200
# Finished simulation 173/200
# Finished simulation 174/200
# Finished simulation 175/200
# Finished simulation 177/200
# Finished simulation 176/200
# Finished simulation 178/200
# Finished simulation 179/200
# Finished simulation 181/200
# Finished simulation 180/200
# Finished simulation 182/200
# Finished simulation 183/200
# Finished simulation 184/200
# Finished simulation 186/200
# Finished simulation 185/200
# Finished simulation 187/200
# Finished simulation 188/200
# Finished simulation 189/200
# Finished simulation 190/200
# Finished simulation 193/200
# Finished simulation 191/200
# Finished simulation 194/200
# Finished simulation 192/200
# Finished simulation 195/200
# Finished simulation 196/200
# Finished simulation 197/200
# Finished simulation 198/200
# Finished simulation 199/200
# Finished simulation 200/200
# Saved results to: ../expectedoutput/trialest_lfi-2560.npz

# %% [markdown]
# #### 5.2 representation drift

# %%
data = np.load('../exampledata/driftcheck.npz')
glm_r2_all=data['glm_r2_all']
beta_session=data['beta_session']
stim_session=data['stim_session']

nsess = 8

# %%
# GLM R2 (https://www.nature.com/articles/s41593-021-00962-x#Fig2, NSD)
mglm_r2 = np.nanmedian(glm_r2_all,axis=2) # subj x roi x session

f=plt.figure(figsize=(15,3))
for roi_i, roi in enumerate(roi_labels):
    plt.subplot(1,len(roi_labels),roi_i+1)
    mybarplot(mglm_r2[:,roi_i,:],'mean','sem','k','Session','GLM R2',np.arange(1,1+nsess),[],'',1,1,bartype='ind')
    plt.ylim([0,0.82])
    plt.title(roi)
    # one-way rm-anova
    data_forstat = mglm_r2[:,roi_i,:]
    df = pd.DataFrame({
        'subject': np.repeat(np.arange(len(subjs)), nsess),
        'session': np.tile(np.arange(nsess), len(subjs)),
        'value': data_forstat.flatten()
    })
    aov = pg.rm_anova(data=df, dv='value', within='session', subject='subject', detailed=True)
    p = aov['p-unc'].iloc[0]
    print('{:.3f}'.format(p),end='\t')
# Out:
# 0.255	0.110	0.161

# %%
# mean response: 
r_session = np.nanmean(beta_session,axis=-1) # task x roi x subj x 8sess x 100
mr_session = np.nanmedian(r_session,axis=-1) # task x roi x subj x 8sess
# bar group
f=plt.figure(figsize=(15,5))
for task_i in range(len(tasks)):
    for roi_i, roi in enumerate(roi_labels):
        plt.subplot(2,len(roi_labels),task_i*len(roi_labels)+roi_i+1)
        mybarplot(mr_session[task_i,roi_i,:,:],'mean','sem',cm[task_i],'Session','',np.arange(1,1+nsess),[],'',1,1,bartype='ind')
        plt.title(roi)
        #plt.ylim([-0.5,3.5])

        # one-way rm-anova
        data_forstat = mr_session[task_i,roi_i,:]
        df = pd.DataFrame({
            'subject': np.repeat(np.arange(len(subjs)), nsess),
            'session': np.tile(np.arange(nsess), len(subjs)),
            'value': data_forstat.flatten()
        })
        aov = pg.rm_anova(data=df, dv='value', within='session', subject='subject', detailed=True)
        p = aov['p-unc'].iloc[0]
        print('{:.4f}'.format(p),end='\t')
        if p < 0.05:
            posthoc = pg.pairwise_tests(
                data=df,
                dv='value',
                within='session',
                subject='subject',
                padjust='bonferroni',
                effsize='cohen'
            )
            #print(posthoc)
    print()
# Out:
# 0.5663	0.5249	0.4310
# 0.3351	0.1777	0.0793

# %%
# mean variability: 
var_session = np.nanvar(beta_session,axis=-1) # 2 x 7 x 8 x 8 x 100
mvar_session = np.nanmedian(var_session,axis=-1) # 2 x 7 x 8 x 8
# bar group
f=plt.figure(figsize=(15,5))
for task_i in range(len(tasks)):
    for roi_i, roi in enumerate(roi_labels):
        plt.subplot(2,len(roi_labels),task_i*len(roi_labels)+roi_i+1)
        mybarplot(mvar_session[task_i,roi_i,:,:],'mean','sem',cm[task_i],'Session','',np.arange(1,nsess+1),[],'',1,1,bartype='ind')
        plt.title(roi)
        #plt.ylim([0,8])
        # one-way rm-anova
        data_forstat = mvar_session[task_i,roi_i,:]
        df = pd.DataFrame({
            'subject': np.repeat(np.arange(len(subjs)), nsess),
            'session': np.tile(np.arange(nsess), len(subjs)),
            'value': data_forstat.flatten()
        })
        aov = pg.rm_anova(data=df, dv='value', within='session', subject='subject', detailed=True)
        p = aov['p-unc'].iloc[0]
        print('{:.4f}'.format(p),end='\t')
# Out:
# 0.2753	0.2996	0.2653	0.1961	0.3574	0.5155

# %%
# correlation: 
corr_session = corr_batch_nan(beta_session,ctype='corr',ddof=1) # 2 x 7 x 8 x 8 x 100 x 100
triu_idx = np.triu_indices(nvoxel,k=1)
corr_triu = corr_session[...,triu_idx[0],triu_idx[1]] # 2 x 7 x 8 x 8 x 4950
mcorr_session = np.nanmedian(corr_triu,axis=-1) # 2 x 7 x 8 x 8
mcorr_session_fisherz = fisherztrans(mcorr_session)
# bar group
f=plt.figure(figsize=(15,5))
for task_i in range(len(tasks)):
    for roi_i, roi in enumerate(roi_labels):
        plt.subplot(2,len(roi_labels),task_i*len(roi_labels)+roi_i+1)
        mybarplot(mcorr_session[task_i,roi_i,:,:],'mean','sem',cm[task_i],'Session','',np.arange(1,nsess+1),[],'',1,1,bartype='ind')
        plt.title(roi)
        #plt.ylim([0,0.55])
        # one-way rm-anova
        data_forstat = mcorr_session_fisherz[task_i,roi_i,:]
        df = pd.DataFrame({
            'subject': np.repeat(np.arange(len(subjs)), nsess),
            'session': np.tile(np.arange(nsess), len(subjs)),
            'value': data_forstat.flatten()
        })
        aov = pg.rm_anova(data=df, dv='value', within='session', subject='subject', detailed=True)
        p = aov['p-unc'].iloc[0]
        print('{:.4f}'.format(p),end='\t')
    print()
# Out:
# 0.9711	0.3323	0.9128
# 0.9918	0.3018	0.7291

# %%
from joblib import Parallel, delayed

def cal_dfnorm(beta_all,stimposicond_all):
    '''
    return: [npos,npos,nsubj,nroi,ntask]
    '''

    ntask,nroi,nsubj,nvoxel,_ = beta_all.shape
    npos = len(np.unique(stimposicond_all[~np.isnan(stimposicond_all)]))
    dfnorm_ij_all = np.zeros((npos,npos,nsubj,nroi,ntask)) # [npos(s1),npos(s2),nsubj,nroi,ntask]
    for task_i in range(ntask):
        for roi_i in range(nroi):
            for subj_i in range(nsubj):
                stimposicond = stimposicond_all[task_i,subj_i]
                beta_mean = np.zeros((nvoxel,npos))*np.nan
                for pos in range(npos):
                    beta_mean[:,pos] = np.nanmean(beta_all[task_i,roi_i,subj_i,:,stimposicond==pos].T,axis=1)
                for s1 in range(npos):
                    dfnorm_ij_all[s1,:,subj_i,roi_i,task_i] = np.linalg.norm(beta_mean[:,s1] - beta_mean.T,axis=1)
    
    return dfnorm_ij_all

def cal_ullambda(beta_all,stimposicond_all):
    '''
    return: [npos,npos,nsubj,nroi,ntask]
    '''
    ntask,nroi,nsubj,nvoxel,_ = beta_all.shape
    npos = len(np.unique(stimposicond_all[~np.isnan(stimposicond_all)]))
    ullambda_ij_all = np.zeros((npos,npos,nsubj,nroi,ntask)) # [npos(s1),npos(s2),nsubj,nroi,ntask]
    for task_i in range(ntask):
        for roi_i in range(nroi):
            for subj_i in range(nsubj):
                stimposicond = stimposicond_all[task_i,subj_i]
                beta = beta_all[task_i,roi_i,subj_i,:]
                for s1 in range(npos):
                    for s2 in range(s1, npos):
                        var1 = np.nanvar(beta[:,stimposicond==s1].T,axis=1,ddof=1)
                        var2 = np.nanvar(beta[:,stimposicond==s2].T,axis=1,ddof=1)
                        ullambda_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,task_i] = np.nanmean((var1+var2)/2)
    
    return ullambda_ij_all


def cal_srdw(beta_all,stimposicond_all):
    '''
    input: 
        - beta_all: [task, roi, subj, voxel, trial]
        - stimposicond_all: [task, subj, trial]
    output:
        - vals_ij_all: [npos,npos,nsubj,nroi,ntask]
    '''
    ntask, nroi, nsubj, nvoxel, _ = beta_all.shape
    npos = len(np.unique(stimposicond_all[~np.isnan(stimposicond_all)]))
    ntrialperpos = np.max([np.sum(stimposicond_all[task_i,subj_i,:]==pos) for pos in range(npos) for task_i in range(ntask) for subj_i in range(nsubj)])

    vals_ij_all = np.zeros((npos,npos,nsubj,nroi,ntask)) # [npos(s1),npos(s2),nsubj,nroi,ntask]
    for task_i in range(ntask):
        for roi_i in range(nroi):
            for subj_i in range(nsubj):
                stimposicond = stimposicond_all[task_i,subj_i,:]
                beta_cond = np.zeros((nvoxel,ntrialperpos,npos))*np.nan 
                beta_mean_cond = np.zeros((nvoxel,npos))*np.nan
                for pos in range(npos):
                    b = beta_all[task_i,roi_i,subj_i,:,stimposicond==pos].T
                    beta_cond[:,:b.shape[1],pos] = b
                    beta_mean_cond[:,pos] = np.nanmean(beta_cond[:,:,pos],axis=1)
                for s1 in range(npos-1):
                    for s2 in range(s1+1,npos):
                        _,df,dfnorm,v,_,htlambda = cal_lfi_param(beta_mean_cond,beta_cond,s1,s2)
                        dfunit = df/dfnorm
                        vals_ij_all[[s1,s2],[s2,s1],subj_i,roi_i,task_i] = np.nansum([(dfunit@v[:,i])**2/htlambda[i] for i in range(len(htlambda))])

    return vals_ij_all

def cal_lfi_param(beta_mean_cond,beta_cond,s1,s2):
    # ds
    dr = s1//4-s2//4
    dc = s1%4-s2%4
    ds = ds0 *  (dr**2+dc**2)**0.5
    # df & |dfnorm|
    df = np.mat(beta_mean_cond[:,s1] - beta_mean_cond[:,s2])
    dfnorm = np.linalg.norm(df,axis=1)
    # eigenvector & eigenvalue
    beta_cond_s1 = beta_cond[:,:,s1]
    beta_cond_s2 = beta_cond[:,:,s2]
    beta_cond_s1 = beta_cond_s1[:,np.all(np.isfinite(beta_cond_s1),axis=0)]
    beta_cond_s2 = beta_cond_s2[:,np.all(np.isfinite(beta_cond_s2),axis=0)]
    q1 = np.cov(beta_cond_s1)
    q2 = np.cov(beta_cond_s2)
    q = (q1 + q2)/2
    w,v = np.linalg.eigh(q)
    ullambda = np.nanmean(w)
    htlambda = w/ullambda
    return ds,df,dfnorm,v,ullambda,htlambda


def srdw_leaveoneout(beta_session,stim_session):
    npos = len(np.unique(stim_session[~np.isnan(stim_session)]))
    ntask, nroi, nsubj, nsession,nvoxel,ntrial = beta_session.shape
    vals_ij_all = np.full([npos,npos,nsubj,nroi,ntask,nsession],np.nan)
    for ss in tqdm(range(nsession)):
        beta_tmp = beta_session.transpose(0,1,2,4,5,3).copy()
        beta_tmp[...,ss] = np.nan
        stim_tmp = stim_session.transpose(0,1,3,2).copy()
        stim_tmp[...,ss] = np.nan
        beta_tmp = beta_tmp.reshape([ntask,nroi,nsubj,nvoxel,nsession*ntrial])
        stim_tmp = stim_tmp.reshape([ntask,nsubj,nsession*ntrial])
        vals_ij_all[...,ss] = cal_srdw(beta_tmp,stim_tmp)

    return vals_ij_all
        

def metric_distance(metric_ij_all):
    '''
    input: metric_ij_all [npos,npos,nsubj,nroi,ntask,...]
    output: metric_d_subj [d,nsubj,nroi,ntask,...]
    '''
    # average dfnorm across position pairs for each distance for each subject
    metric_d_subj = np.full([len(d)]+list(metric_ij_all.shape[2:]),np.nan) # d x subj x roi x task x ...
    for dd in range(len(d)):
        metric_d_subj[dd,:,:,:] = np.nanmean(metric_ij_all[ds_list==d[dd],:,:,:],axis=0)
    
    return metric_d_subj

# %%
ntask,nroi,nsubj,nsession,nvoxel,_ = beta_session.shape

# |df|
dfnorm_ij_session = np.full([npos,npos,nsubj,nroi,ntask,nsession],np.nan)
for session_i in range(nsession):
    dfnorm_ij_session[...,session_i] = cal_dfnorm(beta_session[:,:,:,session_i,:,:],stim_session[:,:,session_i,:])

logdfnorm_ij_session = np.log(dfnorm_ij_session)
logdfnorm_ij_session[np.isinf(logdfnorm_ij_session)] = np.nan

logdfnorm_d_session = metric_distance(logdfnorm_ij_session) # d x subj x roi x task x session

# <lambda>
ullambda_ij_session = np.full([npos,npos,nsubj,nroi,ntask,nsession],np.nan)
for session_i in range(nsession):
    ullambda_ij_session[...,session_i] = cal_ullambda(beta_session[:,:,:,session_i,:,:],stim_session[:,:,session_i,:])

logullambda_ij_session = np.log(ullambda_ij_session)
logullambda_ij_session[np.isinf(logullambda_ij_session)] = np.nan

logullambda_d_session = metric_distance(logullambda_ij_session)


# <dfunit,w,v> leave-one-out
vals_ij_session = srdw_leaveoneout(beta_session,stim_session)
# [npos,npos,nsubj,nroi,ntask,nsession]

logvals_ij_session = np.log(vals_ij_session)
logvals_ij_session[np.isinf(logvals_ij_session)] = np.nan

logvals_d_session = metric_distance(logvals_ij_session)


np.savez('../expectedoutput/driftcheck_session_loo.npz',
    logdfnorm_d_session = logdfnorm_d_session,
    logullambda_d_session = logullambda_d_session,
    logvals_d_session = logvals_d_session,
    )
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_36868\3212071752.py:8: RuntimeWarning: divide by zero encountered in log
#   logdfnorm_ij_session = np.log(dfnorm_ij_session)
# 100%|██████████| 8/8 [00:34<00:00,  4.25s/it]
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_36868\3212071752.py:28: RuntimeWarning: divide by zero encountered in log
#   logvals_ij_session = np.log(vals_ij_session)
